# %%
#1.- Importar archivos 
import pandas as pd

# %%
#Read the three files into python as dataframes
file1 = pd.read_csv("file1lab.csv")
file2 = pd.read_csv("file2lab.csv")
file3 = pd.read_csv("file3lab.csv")

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#Show the DataFrame's shape.
print(file1.shape)
print(file2.shape)
print(file3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
# Standardize header names.
columnas_1 = pd.DataFrame(file1.columns)
columnas_2 = pd.DataFrame(file2.columns)
columnas_3 = pd.DataFrame(file3.columns)

Compara = pd.concat([columnas_1,columnas_2,columnas_3], axis=1)
Compara
# Out:
#                             0                          0  \
# 0                    Customer                   Customer
# 1                          ST                         ST
# 2                      GENDER                     GENDER
# 3                   Education                  Education
# 4     Customer Lifetime Value    Customer Lifetime Value
# 5                      Income                     Income
# 6        Monthly Premium Auto       Monthly Premium Auto
# 7   Number of Open Complaints  Number of Open Complaints
# 8                 Policy Type         Total Claim Amount
# 9               Vehicle Class                Policy Type
# 10         Total Claim Amount              Vehicle Class
#
#                             0
# 0                    Customer
# 1                       State
# 2     Customer Lifetime Value
# 3                   Education
# 4                      Gender
# 5                      Income
# 6        Monthly Premium Auto
# ...

# %%
#Estas son las que usare para todas
file3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
#PONIENDO  LOS NOMBRES DE LAS COLUMNAS DE FILE 1 IGUALES A LAS DE FILE 3 (SIN ORDENAR)
file1.columns=['Customer', 'State','Gender','Education', 'Customer Lifetime Value', 
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount']
print(file1.columns)
#PONIENDO  LOS NOMBRES DE LAS COLUMNAS DE FILE 2 IGUALES A LAS DE FILE 3 (SIN ORDENAR)
file2.columns=['Customer', 'State','Gender','Education', 'Customer Lifetime Value', 
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Total Claim Amount','Policy Type', 'Vehicle Class' ]
print(file2.columns)
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
columnas_1 = pd.DataFrame(file1.columns)
columnas_2 = pd.DataFrame(file2.columns)
columnas_3 = pd.DataFrame(file3.columns)

Compara = pd.concat([columnas_1,columnas_2,columnas_3], axis=1)
Compara
#falta reordenar
# Out:
#                             0                          0  \
# 0                    Customer                   Customer
# 1                       State                      State
# 2                      Gender                     Gender
# 3                   Education                  Education
# 4     Customer Lifetime Value    Customer Lifetime Value
# 5                      Income                     Income
# 6        Monthly Premium Auto       Monthly Premium Auto
# 7   Number of Open Complaints  Number of Open Complaints
# 8                 Policy Type         Total Claim Amount
# 9               Vehicle Class                Policy Type
# 10         Total Claim Amount              Vehicle Class
#
#                             0
# 0                    Customer
# 1                       State
# 2     Customer Lifetime Value
# 3                   Education
# 4                      Gender
# 5                      Income
# 6        Monthly Premium Auto
# ...

# %%
#Rearrange the columns in the dataframe as needed
#Todas mantendran el orden de file1
#Modificaremos el orden en file2
file2=file2.reindex(columns=['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount'])
file2
# Out:
#     Customer       State Gender Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
#Modificaremos el orden en file3
file3=file3.reindex(columns=['Customer', 'State', 'Gender', 'Education', 'Customer Lifetime Value',
       'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
       'Policy Type', 'Vehicle Class', 'Total Claim Amount'])
file3
# Out:
#      Customer       State Gender             Education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
#Volvemos a comparar
columnas_1 = pd.DataFrame(file1.columns)
columnas_2 = pd.DataFrame(file2.columns)
columnas_3 = pd.DataFrame(file3.columns)

Compara = pd.concat([columnas_1,columnas_2,columnas_3], axis=1)
Compara
#Ya esta
# Out:
#                             0                          0  \
# 0                    Customer                   Customer
# 1                       State                      State
# 2                      Gender                     Gender
# 3                   Education                  Education
# 4     Customer Lifetime Value    Customer Lifetime Value
# 5                      Income                     Income
# 6        Monthly Premium Auto       Monthly Premium Auto
# 7   Number of Open Complaints  Number of Open Complaints
# 8                 Policy Type                Policy Type
# 9               Vehicle Class              Vehicle Class
# 10         Total Claim Amount         Total Claim Amount
#
#                             0
# 0                    Customer
# 1                       State
# 2                      Gender
# 3                   Education
# 4     Customer Lifetime Value
# 5                      Income
# 6        Monthly Premium Auto
# ...

# %%
#Concatenate the three dataframes
data = pd.concat([file1,file2,file3], axis=0)
data
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#Which columns are numerical?
#hay que sacar los tipos de datos
#  Customer Life Time Value
#  Income
#  Montly Premium Auto
#  Number of Open Complains
#  Total Claim Amount

# %%
#Which columns are categorical?
#  Customer
#  State
#  Gender
#  Education
#  Policy type
#  Vehicle Class

# %%
#Understand the meaning of all columns
#  Customer Life Time Value: el dinero que te generara el cliente hasta que se muera
#  Income: el ingreso del cliente
#  Montly Premium Auto : Prima mensual
#  Number of Open Complaints: Numero de quejaas
#  Total Claim Amount: Importe Total de la reclamacion
#  Customer: Cliente 
#  State : Estado donde vive el cliente
#  Gender: Genero del Cliente
#  Education: Maximo Grado de estudios
#  Policy type: Tipo de poliza
#  Vehicle Class: Tipo de Vehiculo

# %%
#Perform the data cleaning operations mentioned so far in class
#Delete the column education and the number of open complaints from the dataframe.
data=data.drop(['Education','Number of Open Complaints'], axis=1)
data
# Out:
#      Customer       State Gender Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Voy a eliminar los % por que me estorban
data['Customer Lifetime Value'] = data['Customer Lifetime Value'].replace({'%':''}, regex=True)
data
# Out:
#      Customer       State Gender Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
data['Customer Lifetime Value']=data['Customer Lifetime Value']*100
data
# Out:
#      Customer       State Gender  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 2     AI49188      Nevada      F
# 3     WW63253  California      M
# 4     GA49547  Washington      M
# ...       ...         ...    ...
# 7065  LA72316  California      M
# 7066  PK87824  California      F
# 7067  TD14365  California      M
# 7068  UP19263  California      M
# 7069  Y167826  California      M
#
#                                 Customer Lifetime Value   Income  \
# 0                                                   NaN      0.0
# 1     697953.59697953.59697953.59697953.59697953.596...      0.0
# 2     1288743.171288743.171288743.171288743.17128874...  48767.0
# 3     764586.18764586.18764586.18764586.18764586.187...      0.0
# 4     536307.65536307.65536307.65536307.65536307.655...  36357.0
# ...                                                 ...      ...
# 7065                                        2340598.798  71941.0
# ...

# %%
#and change dtype to numerical type.
data['Customer Lifetime Value'] =  pd.to_numeric(data['Customer Lifetime Value'], errors='coerce')
data.dtypes
# Out:
# Customer                    object
# State                       object
# Gender                      object
# Customer Lifetime Value    float64
# Income                     float64
# Monthly Premium Auto       float64
# Policy Type                 object
# Vehicle Class               object
# Total Claim Amount         float64
# dtype: object

# %%
#Check for duplicate rows in the data 
#Numero de Duplicados
data.duplicated().sum()
# Out:
# 2939

# %%
#and remove if any.
data1=data.drop_duplicates()
data1
# Out:
#      Customer       State Gender  Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                      NaN      0.0
# 2     AI49188      Nevada      F                      NaN  48767.0
# 3     WW63253  California      M                      NaN      0.0
# 4     GA49547  Washington      M                      NaN  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+06  71941.0
# 7066  PK87824  California      F             3.096511e+05  21604.0
# 7067  TD14365  California      M             8.163890e+05      0.0
# 7068  UP19263  California      M             7.524442e+05  21941.0
# 7069  Y167826  California      M             2.611837e+05      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Corroboramos la diferencia de Duplicados
len(data)-len(data1)
# Out:
# 2939

# %%
#Filter out the data for customers who have an income of 0 or less.
data1[(data1['Income']<=0)]
# Out:
#      Customer       State Gender  Customer Lifetime Value  Income  \
# 0     RB50392  Washington    NaN                      NaN     0.0
# 1     QZ44356     Arizona      F                      NaN     0.0
# 3     WW63253  California      M                      NaN     0.0
# 7     CF85061     Arizona      M                      NaN     0.0
# 10    SX51350  California      M                      NaN     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103  California      F             5.678050e+05     0.0
# 7061  RX91025  California      M             1.987226e+06     0.0
# 7062  AC13887  California      M             4.628995e+05     0.0
# 7067  TD14365  California      M             8.163890e+05     0.0
# 7069  Y167826  California      M             2.611837e+05     0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
