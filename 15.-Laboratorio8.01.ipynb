# %% [markdown]
# # <font color='orange'> Lab | Web Scraping Single Page </font>

# %% [markdown]
# - Business goal:
# - Check the case_study_gnod.md file.
# - Make sure you've understood the big picture of your project:
# - the goal of the company (Gnod),
# - their current product (Gnoosic),
# - their strategy, and
# - how your project fits into this context.
# - Re-read the business case and the e-mail from the CTO, take a look at the flowchart and create an initial Trello board with the tasks you think you'll have to accomplish.
# - Instructions - Scraping popular songs
# - Your product will take a song as an input from the user and will output another song (the recommendation).
# In most cases, the recommended song will have to be similar to the inputted song,
# but the CTO thinks that if the song is on the top charts at the moment, the user will enjoy more a recommendation of a song that's also popular at the moment.
# - You have find data on the internet about currently popular songs. Billboard maintains a weekly Top 100 of "hot" songs here: https://www.billboard.com/charts/hot-100.
# - It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.billboard.com/charts/hot-100/'
billboard_html = requests.get(url).content
soup = BeautifulSoup(billboard_html, "html.parser")

# %%
# Encontrar todos los elementos <span> con la clase "chart-element__information__song text--truncate color--primary"
# song titles
songs = soup.find_all("h3", class_="a-no-trucate")

# artists
artists = soup.find_all("span", class_="a-no-trucate")
artists
# Out:
# [<span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet">
#
#  	Miley Cyrus
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	SZA
#  </span>,
#  <span class="c-label a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only">
#
#  	PinkPantheress &amp; Ice Spice
#  </span>,
# ...

# %%
# 6. Get the text
for i in [songs, artists]:
    for j in range(len(i)):
        i[j] = i[j].getText()

# %%
# 7. Build a dataframe

billboard = pd.DataFrame(
    {"song": songs,
     "artist": artists})

# %%
billboard
# Out:
#                                                  song  \
# 0       \n\n\t\n\t\n\t\t\n\t\t\t\t\tFlowers\t\t\n\t\n
# 1     \n\n\t\n\t\n\t\t\n\t\t\t\t\tKill Bill\t\t\n\t\n
# 2   \n\n\t\n\t\n\t\t\n\t\t\t\t\tBoy's A Liar, Pt. ...
# 3      \n\n\t\n\t\n\t\t\n\t\t\t\t\tCreepin'\t\t\n\t\n
# 4    \n\n\t\n\t\n\t\t\n\t\t\t\t\tLast Night\t\t\n\t\n
# ..                                                ...
# 95  \n\n\t\n\t\n\t\t\n\t\t\t\t\tSlut Me Out\t\t\n\t\n
# 96     \n\n\t\n\t\n\t\t\n\t\t\t\t\tLa Jumpa\t\t\n\t\n
# 97  \n\n\t\n\t\n\t\t\n\t\t\t\t\tShut Up My Moms Ca...
# 98         \n\n\t\n\t\n\t\t\n\t\t\t\t\tGold\t\t\n\t\n
# 99     \n\n\t\n\t\n\t\t\n\t\t\t\t\tBack End\t\t\n\t\n
#
#                                             artist
# 0                            \n\t\n\tMiley Cyrus\n
# 1                                    \n\t\n\tSZA\n
# 2             \n\t\n\tPinkPantheress & Ice Spice\n
# 3   \n\t\n\tMetro Boomin, The Weeknd & 21 Savage\n
# 4                          \n\t\n\tMorgan Wallen\n
# ...

# %%
billboard= billboard.replace({'\n':'','\t':'' }, regex=True)
billboard
# Out:
#                        song                                artist
# 0                   Flowers                           Miley Cyrus
# 1                 Kill Bill                                   SZA
# 2       Boy's A Liar, Pt. 2            PinkPantheress & Ice Spice
# 3                  Creepin'  Metro Boomin, The Weeknd & 21 Savage
# 4                Last Night                         Morgan Wallen
# ..                      ...                                   ...
# 95              Slut Me Out                            NLE Choppa
# 96                 La Jumpa                  Arcangel & Bad Bunny
# 97  Shut Up My Moms Calling                            Hotel Ugly
# 98                     Gold                        Dierks Bentley
# 99                 Back End                         Finesse2Tymes
#
# [100 rows x 2 columns]
